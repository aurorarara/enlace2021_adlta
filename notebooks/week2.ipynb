# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
df = pd.read_excel('../data/Educacion_01.xlsx' , skiprows = range(0, 3))

# %%
df.head()
# Out:
#          Entidad federativa       Total  Sabe leer y escribir  \
# 0  Estados Unidos Mexicanos  19529018.0            17554529.0
# 1            Aguascalientes    234498.0              216002.0
# 2           Baja California    553060.0              495977.0
# 3       Baja California Sur    121220.0              107786.0
# 4                  Campeche    145473.0              129890.0
#
#    No sabe leer y escribir  No especificado
# 0                1871713.0         102776.0
# 1                  17770.0            726.0
# 2                  52605.0           4478.0
# 3                  12780.0            654.0
# 4                  14959.0            624.0

# %%
df.rename(columns={'Entidad federativa': 'state', 'Sabe leer y escribir': 'read_write', 'No sabe leer y escribir': 'not_read_write', 'No especificado': 'not_especified'}, inplace=True)

# %%
df.query("state != 'Estados Unidos Mexicanos'", inplace=True)

# %%
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_especified
# 1        Aguascalientes  234498.0    216002.0         17770.0           726.0
# 2       Baja California  553060.0    495977.0         52605.0          4478.0
# 3   Baja California Sur  121220.0    107786.0         12780.0           654.0
# 4              Campeche  145473.0    129890.0         14959.0           624.0
# 5  Coahuila de Zaragoza  486221.0    445183.0         39038.0          2000.0

# %%
df['pct_read_write'] = df['read_write']/df['Total']*100
df['pct_not_read_write'] = df['not_read_write']/df['Total']*100

# %%
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_especified  \
# 1        Aguascalientes  234498.0    216002.0         17770.0           726.0
# 2       Baja California  553060.0    495977.0         52605.0          4478.0
# 3   Baja California Sur  121220.0    107786.0         12780.0           654.0
# 4              Campeche  145473.0    129890.0         14959.0           624.0
# 5  Coahuila de Zaragoza  486221.0    445183.0         39038.0          2000.0
#
#    pct_read_write  pct_not_read_write
# 1       92.112513            7.577890
# 2       89.678697            9.511626
# 3       88.917670           10.542815
# 4       89.288047           10.283008
# 5       91.559805            8.028859

# %%
df['state'] = df['state'].str.upper()

# %%
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_especified  \
# 1        AGUASCALIENTES  234498.0    216002.0         17770.0           726.0
# 2       BAJA CALIFORNIA  553060.0    495977.0         52605.0          4478.0
# 3   BAJA CALIFORNIA SUR  121220.0    107786.0         12780.0           654.0
# 4              CAMPECHE  145473.0    129890.0         14959.0           624.0
# 5  COAHUILA DE ZARAGOZA  486221.0    445183.0         39038.0          2000.0
#
#    pct_read_write  pct_not_read_write
# 1       92.112513            7.577890
# 2       89.678697            9.511626
# 3       88.917670           10.542815
# 4       89.288047           10.283008
# 5       91.559805            8.028859

# %%
df = df.iloc[0:32,:].copy()
df.sort_values(by=['state'], ascending = True, inplace=True)
df.at[9,'state']='DISTRITO FEDERAL'
df.at[5,'state']='COAHUILA'
df.at[15,'state']='MEXICO'
df.at[16,'state']='MICHOACAN'
df.at[30,'state']='VERACRUZ'
df.at[22,'state']='QUERETARO'
df.at[24,'state']='SAN LUIS POTOSI'
df.at[31,'state']='YUCATAN'
# 19        2.847770
# 20        8.040032
# 21        6.272929
# 22       19.439910
# 23        3.523901
# 24        6.240746
# 25        4.683315
# 26        6.764408
# 27        7.231684
# 28        2.898528
# 29        2.974287
# 30       14.784662
# 31        4.140598

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="total_cases", y="pct_not_read_write", data=dfAll)
sns.set_context('paper', font_scale=2)

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="total_cases", y="pct_read_write", data=dfAll)
sns.set_context('paper', font_scale=2)

# %%
df2 = pd.read_excel('../data/Educacion_05.xlsx' , skiprows = range(0, 4))

# %%
df2.head()
# Out:
#          Entidad federativa  Total
# 0  Estados Unidos Mexicanos   9.74
# 1            Aguascalientes  10.35
# 2           Baja California  10.20
# 3       Baja California Sur  10.34
# 4                  Campeche   9.63

# %%
df2.rename(columns={'Entidad federativa': 'state', 'Total': 'average_years_finish'}, inplace=True)

# %%
df2.query("state != 'Estados Unidos Mexicanos'", inplace=True)

# %%
df2.head()
# Out:
#                   state  average_years_finish
# 1        Aguascalientes                 10.35
# 2       Baja California                 10.20
# 3   Baja California Sur                 10.34
# 4              Campeche                  9.63
# 5  Coahuila de Zaragoza                 10.43

# %%
df2['state'] = df2['state'].str.upper()

# %%
df2.head()
# Out:
#                   state  average_years_finish
# 1        AGUASCALIENTES                 10.35
# 2       BAJA CALIFORNIA                 10.20
# 3   BAJA CALIFORNIA SUR                 10.34
# 4              CAMPECHE                  9.63
# 5  COAHUILA DE ZARAGOZA                 10.43

# %%
df2 = df2.iloc[0:32,:].copy()
df2.sort_values(by=['state'], ascending = True, inplace=True)
df2.at[9,'state']='DISTRITO FEDERAL'
df2.at[5,'state']='COAHUILA'
df2.at[15,'state']='MEXICO'
df2.at[16,'state']='MICHOACAN'
df2.at[30,'state']='VERACRUZ'
df2.at[22,'state']='QUERETARO'
df2.at[24,'state']='SAN LUIS POTOSI'
df2.at[31,'state']='YUCATAN'
df2.at[19,'state']='NUEVO LEON'

df2.sort_values(by=['state'], ascending = True, inplace=True)
df2
# Out:
#                   state  average_years_finish
# 1        AGUASCALIENTES                 10.35
# 2       BAJA CALIFORNIA                 10.20
# 3   BAJA CALIFORNIA SUR                 10.34
# 4              CAMPECHE                  9.63
# 7               CHIAPAS                  7.78
# 8             CHIHUAHUA                 10.00
# 5              COAHUILA                 10.43
# 6                COLIMA                 10.05
# 9      DISTRITO FEDERAL                 11.48
# 10              DURANGO                  9.75
# 11           GUANAJUATO                  9.04
# 12             GUERRERO                  8.37
# 13              HIDALGO                  9.37
# 14              JALISCO                  9.90
# 15               MEXICO                 10.08
# 16            MICHOACAN                  8.60
# 17              MORELOS                  9.84
# 18              NAYARIT                  9.73
# 19           NUEVO LEON                 10.74
# 20               OAXACA                  8.12
# 21               PUEBLA                  9.16
# 22            QUERETARO                 10.48
# 23         QUINTANA ROO                 10.24
# 24      SAN LUIS POTOSI                  9.61
# 25              SINALOA                 10.22
# 26               SONORA                 10.40
# 27              TABASCO                  9.69
# 28           TAMAULIPAS                 10.09
# 29             TLAXCALA                  9.83
# 30             VERACRUZ                  8.75
# 31              YUCATAN                  9.59
# 32            ZACATECAS                  9.25

# %%
dfAll2 = pd.merge(df2,dfWeek1,on='state') 
dfAll2
# Out:
#                   state  average_years_finish  population  total_cases  \
# 0        AGUASCALIENTES                 10.35     1434635        26694
# 1       BAJA CALIFORNIA                 10.20     3634868        50278
# 2   BAJA CALIFORNIA SUR                 10.34      804708        36223
# 3              CAMPECHE                  9.63     1000617        11081
# 4               CHIAPAS                  7.78     5730367        12050
# 5             CHIHUAHUA                 10.00     3801487        57483
# 6              COAHUILA                 10.43     3218720        69382
# 7                COLIMA                 10.05      785153        12203
# 8      DISTRITO FEDERAL                 11.48     9018645       673343
# 9               DURANGO                  9.75     1868996        34588
# 10           GUANAJUATO                  9.04     6228175       132650
# 11             GUERRERO                  8.37     3657048        41608
# 12              HIDALGO                  9.37     3086414        39375
# 13              JALISCO                  9.90     8409693        88130
# 14               MEXICO                 10.08    17427790       256656
# 15            MICHOACAN                  8.60     4825401        49057
# 16              MORELOS                  9.84     2044058        34213
# 17              NAYARIT                  9.73     1288571        12532
# 18           NUEVO LEON                 10.74     5610153       126068
# 19               OAXACA                  8.12     4143593        47967
# 20               PUEBLA                  9.16     6604451        85945
# 21            QUERETARO                 10.48     2279637        69561
# 22         QUINTANA ROO                 10.24     1723259        30675
# 23      SAN LUIS POTOSI                  9.61     2866142        65040
# 24              SINALOA                 10.22     3156674        41019
# 25               SONORA                 10.40     3074745        77824
# 26              TABASCO                  9.69     2572287        73463
# 27           TAMAULIPAS                 10.09     3650602        63122
# 28             TLAXCALA                  9.83     1380011        20111
# 29             VERACRUZ                  8.75     8539862        63649
# 30              YUCATAN                  9.59     2259098        44329
# 31            ZACATECAS                  9.25     1666426        30964
#
#     cases_rates  rates_cases60  total_deaths  rates_deaths  rates_deaths60
# 0   1860.682334      55.275384          2456    171.193370        5.924852
# 1   1383.213916      64.624080          8648    237.917856        4.786969
# 2   4501.384353     778.667542          1486    184.663257       14.415167
# 3   1107.416724     162.699614          1265    126.421998        5.596547
# 4    210.283216      19.108724          1654     28.863771        0.715486
# 5   1512.118810     119.505867          7493    197.107079       10.758948
# 6   2155.577372      41.755729          6376    198.091167        2.081573
# 7   1554.219369     130.547804          1210    154.110091        4.330366
# 8   7466.121574     360.187146         34458    382.075134        7.096410
# 9   1850.619263      63.403025          2495    133.494133        3.691822
# 10  2129.837392      36.639947         11079    177.885175        1.878560
# 11  1137.748260      60.595322          4547    124.335256        4.757936
# 12  1275.752378      39.236473          6268    203.083579        4.730409
# 13  1047.957399      34.424562         12604    149.874674        3.139235
# 14  1472.682423      48.881700         37207    213.492359        4.171499
# 15  1016.640897      32.349643          5938    123.057130        5.222364
# 16  1673.778337      96.425835          3536    172.989220        8.218945
# 17   972.550213      64.102017          1868    144.966789        5.277164
# 18  2247.140140      84.061879          9692    172.758212        3.671914
# 19  1157.618521      46.071127          3896     94.024679        2.847770
# 20  1301.319368      43.576673         12171    184.284810        8.040032
# 21  3051.406869      96.155660          4452    195.294251        6.272929
# 22  1780.057438     459.942469          2940    170.606972       19.439910
# 23  2269.252535      80.700817          5428    189.383499        3.523901
# 24  1299.437319     101.689310          6362    201.541242        6.240746
# 25  2531.071682     154.289217          6739    219.172647        4.683315
# 26  2855.941036     390.547400          4234    164.600606        6.764408
# 27  1729.084682     189.913883          5167    141.538300        7.231684
# 28  1457.307224      42.390966          2525    182.969556        2.898528
# 29   745.316493      45.691605         10063    117.835628        2.974287
# 30  1962.243338     329.467779          4098    181.399833       14.784662
# 31  1858.108311      70.870234          2832    169.944540        4.140598

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="total_cases", y="average_years_finish", data=dfAll2)
sns.set_context('paper', font_scale=2)

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="cases_rates", y="pct_not_read_write", data=dfAll)
sns.set_context('paper', font_scale=2)

# %% [markdown]
# Housing

# %%
df2 = pd.read_excel('../data/Vivienda_02.xlsx' , skiprows = range(0, 3))

# %%
df2.head()
# Out:
#          Entidad federativa  2020
# 0  Estados Unidos Mexicanos   3.6
# 1            Aguascalientes   3.7
# 2           Baja California   3.3
# 3       Baja California Sur   3.3
# 4                  Campeche   3.6

# %%
df2.rename(columns={'Entidad federativa': 'state', '2020': 'Average_occupants'}, inplace=True)

# %%
df2.query("state != 'Estados Unidos Mexicanos'", inplace=True)

# %%
df2.head()
# Out:
#                   state  Average_occupants
# 1        Aguascalientes                3.7
# 2       Baja California                3.3
# 3   Baja California Sur                3.3
# 4              Campeche                3.6
# 5  Coahuila de Zaragoza                3.5

# %%
df2['state'] = df2['state'].str.upper()

# %%
df2.head()
# Out:
#                   state  Average_occupants
# 1        AGUASCALIENTES                3.7
# 2       BAJA CALIFORNIA                3.3
# 3   BAJA CALIFORNIA SUR                3.3
# 4              CAMPECHE                3.6
# 5  COAHUILA DE ZARAGOZA                3.5

# %%
df2 = df2.iloc[0:32,:].copy()
df2.sort_values(by=['state'], ascending = True, inplace=True)
df2.at[9,'state']='DISTRITO FEDERAL'
df2.at[5,'state']='COAHUILA'
df2.at[15,'state']='MEXICO'
df2.at[16,'state']='MICHOACAN'
df2.at[30,'state']='VERACRUZ'
df2.at[22,'state']='QUERETARO'
df2.at[24,'state']='SAN LUIS POTOSI'
df2.at[31,'state']='YUCATAN'
df2.at[19,'state']='NUEVO LEON'

df2.sort_values(by=['state'], ascending = True, inplace=True)
df2
# Out:
#                   state  Average_occupants
# 1        AGUASCALIENTES                3.7
# 2       BAJA CALIFORNIA                3.3
# 3   BAJA CALIFORNIA SUR                3.3
# 4              CAMPECHE                3.6
# 7               CHIAPAS                4.1
# 8             CHIHUAHUA                3.2
# 5              COAHUILA                3.5
# 6                COLIMA                3.2
# 9      DISTRITO FEDERAL                3.3
# 10              DURANGO                3.7
# 11           GUANAJUATO                3.9
# 12             GUERRERO                3.7
# 13              HIDALGO                3.6
# 14              JALISCO                3.6
# 15               MEXICO                3.7
# 16            MICHOACAN                3.7
# 17              MORELOS                3.5
# 18              NAYARIT                3.4
# 19           NUEVO LEON                3.5
# 20               OAXACA                3.7
# 21               PUEBLA                3.8
# 22            QUERETARO                3.5
# 23         QUINTANA ROO                3.2
# 24      SAN LUIS POTOSI                3.6
# 25              SINALOA                3.5
# 26               SONORA                3.3
# 27              TABASCO                3.6
# 28           TAMAULIPAS                3.3
# 29             TLAXCALA                3.9
# 30             VERACRUZ                3.4
# 31              YUCATAN                3.5
# 32            ZACATECAS                3.7

# %%
dfAll2 = pd.merge(df2,dfWeek1,on='state') 
dfAll2
# Out:
#                   state  Average_occupants  population  total_cases  \
# 0        AGUASCALIENTES                3.7     1434635        26694
# 1       BAJA CALIFORNIA                3.3     3634868        50278
# 2   BAJA CALIFORNIA SUR                3.3      804708        36223
# 3              CAMPECHE                3.6     1000617        11081
# 4               CHIAPAS                4.1     5730367        12050
# 5             CHIHUAHUA                3.2     3801487        57483
# 6              COAHUILA                3.5     3218720        69382
# 7                COLIMA                3.2      785153        12203
# 8      DISTRITO FEDERAL                3.3     9018645       673343
# 9               DURANGO                3.7     1868996        34588
# 10           GUANAJUATO                3.9     6228175       132650
# 11             GUERRERO                3.7     3657048        41608
# 12              HIDALGO                3.6     3086414        39375
# 13              JALISCO                3.6     8409693        88130
# 14               MEXICO                3.7    17427790       256656
# 15            MICHOACAN                3.7     4825401        49057
# 16              MORELOS                3.5     2044058        34213
# 17              NAYARIT                3.4     1288571        12532
# 18           NUEVO LEON                3.5     5610153       126068
# 19               OAXACA                3.7     4143593        47967
# 20               PUEBLA                3.8     6604451        85945
# 21            QUERETARO                3.5     2279637        69561
# 22         QUINTANA ROO                3.2     1723259        30675
# 23      SAN LUIS POTOSI                3.6     2866142        65040
# 24              SINALOA                3.5     3156674        41019
# 25               SONORA                3.3     3074745        77824
# 26              TABASCO                3.6     2572287        73463
# 27           TAMAULIPAS                3.3     3650602        63122
# 28             TLAXCALA                3.9     1380011        20111
# 29             VERACRUZ                3.4     8539862        63649
# 30              YUCATAN                3.5     2259098        44329
# 31            ZACATECAS                3.7     1666426        30964
#
#     cases_rates  rates_cases60  total_deaths  rates_deaths  rates_deaths60
# 0   1860.682334      55.275384          2456    171.193370        5.924852
# 1   1383.213916      64.624080          8648    237.917856        4.786969
# 2   4501.384353     778.667542          1486    184.663257       14.415167
# 3   1107.416724     162.699614          1265    126.421998        5.596547
# 4    210.283216      19.108724          1654     28.863771        0.715486
# 5   1512.118810     119.505867          7493    197.107079       10.758948
# 6   2155.577372      41.755729          6376    198.091167        2.081573
# 7   1554.219369     130.547804          1210    154.110091        4.330366
# 8   7466.121574     360.187146         34458    382.075134        7.096410
# 9   1850.619263      63.403025          2495    133.494133        3.691822
# 10  2129.837392      36.639947         11079    177.885175        1.878560
# 11  1137.748260      60.595322          4547    124.335256        4.757936
# 12  1275.752378      39.236473          6268    203.083579        4.730409
# 13  1047.957399      34.424562         12604    149.874674        3.139235
# 14  1472.682423      48.881700         37207    213.492359        4.171499
# 15  1016.640897      32.349643          5938    123.057130        5.222364
# 16  1673.778337      96.425835          3536    172.989220        8.218945
# 17   972.550213      64.102017          1868    144.966789        5.277164
# 18  2247.140140      84.061879          9692    172.758212        3.671914
# 19  1157.618521      46.071127          3896     94.024679        2.847770
# 20  1301.319368      43.576673         12171    184.284810        8.040032
# 21  3051.406869      96.155660          4452    195.294251        6.272929
# 22  1780.057438     459.942469          2940    170.606972       19.439910
# 23  2269.252535      80.700817          5428    189.383499        3.523901
# 24  1299.437319     101.689310          6362    201.541242        6.240746
# 25  2531.071682     154.289217          6739    219.172647        4.683315
# 26  2855.941036     390.547400          4234    164.600606        6.764408
# 27  1729.084682     189.913883          5167    141.538300        7.231684
# 28  1457.307224      42.390966          2525    182.969556        2.898528
# 29   745.316493      45.691605         10063    117.835628        2.974287
# 30  1962.243338     329.467779          4098    181.399833       14.784662
# 31  1858.108311      70.870234          2832    169.944540        4.140598

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="cases_rates", y="Average_occupants", data=dfAll2)
sns.set_context('paper', font_scale=2)

# %%
df[['pct_read_write','pct_not_read_write']].describe()
# Out:
#        pct_read_write  pct_not_read_write
# count       32.000000           32.000000
# mean        89.953656            9.575914
# std          2.241227            2.293174
# min         80.801686            6.517517
# 25%         89.168267            8.004238
# 50%         90.080843            9.431692
# 75%         91.573252           10.332385
# max         92.839593           18.898393

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.pairplot(penguins)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.pairplot(df[['pct_read_write', 'pct_not_read_write']]);

# %%
df.head()
# Out:
#                  state      Total  read_write  not_read_write  not_especified  \
# 1       AGUASCALIENTES   234498.0    216002.0         17770.0           726.0
# 2      BAJA CALIFORNIA   553060.0    495977.0         52605.0          4478.0
# 3  BAJA CALIFORNIA SUR   121220.0    107786.0         12780.0           654.0
# 4             CAMPECHE   145473.0    129890.0         14959.0           624.0
# 7              CHIAPAS  1072615.0    866691.0        202707.0          3217.0
#
#    pct_read_write  pct_not_read_write
# 1       92.112513            7.577890
# 2       89.678697            9.511626
# 3       88.917670           10.542815
# 4       89.288047           10.283008
# 7       80.801686           18.898393

# %%
sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(read_write[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-2d0597a235d0> in <module>
#       4 rs = np.random.RandomState(33)
#       5 d = pd.DataFrame(data=rs.normal(size=(100, 26)),
# ----> 6                  columns=list(read_write[26:]))
#       7
#       8 # Compute the correlation matrix
#
# NameError: name 'read_write' is not defined
